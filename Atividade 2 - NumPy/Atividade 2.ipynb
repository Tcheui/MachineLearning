# %% [markdown]
# # Atividade 2

# %% [markdown]
# **Data:**  05/04/2023
# **Nome:**  Gabriel Toshiyuki Batista Toyoda

# %% [markdown]
# ## Instruções
#
# Acrescente suas próprias células para responder os enunciados.
#
# Ao finalizar, submeta a atividade através do ColabWeb.

# %% [markdown]
# # Manipulação de vetores

# %% [markdown]
# <div style="background-color: #E2A038; border: #E2A038 solid 1px; margin-left: 2em; padding-left: 5px"><div style="background-color: #F5EEE3; width: 100%; padding: 10px">
#
# Utilize o NumPy para gerar uma coleção de 10 números aleatórios uniformemente distribuídos no intervalo $[0,1)$.
#
# </div></div>

# %%
import numpy as np

colecao = np.random.rand(10)
colecao
# Out:
# array([0.77795211, 0.40244042, 0.95252385, 0.9196793 , 0.8918009 ,
#        0.97503377, 0.01068349, 0.03750168, 0.39424838, 0.33817461])

# %% [markdown]
# <div style="background-color: #E2A038; border: #E2A038 solid 1px; margin-left: 2em; padding-left: 5px"><div style="background-color: #F5EEE3; width: 100%; padding: 10px">
#
# Utilize o PyPlot para gerar um histograma dessa coleção.
#
# </div></div>

# %%
import matplotlib.pyplot as plt

plt.hist(colecao);

# %% [markdown]
# <div style="background-color: #E2A038; border: #E2A038 solid 1px; margin-left: 2em; padding-left: 5px"><div style="background-color: #F5EEE3; width: 100%; padding: 10px">
#
# Esse histograma não se parece muito com o que esperaríamos... tente uma coleção maior.
#
# </div></div>

# %%
colecao = np.random.rand(1000)
plt.hist(colecao)
# Out:
# (array([ 94., 109., 101., 109., 106., 106., 100.,  83.,  90., 102.]),
#  array([4.34939264e-04, 1.00375442e-01, 2.00315945e-01, 3.00256448e-01,
#         4.00196951e-01, 5.00137454e-01, 6.00077957e-01, 7.00018460e-01,
#         7.99958963e-01, 8.99899466e-01, 9.99839969e-01]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Distribuições de variáveis aleatórias

# %% [markdown]
# Um importante resultado da estatística é o Teorema do Limite Central. Ele diz que o valor médio de uma coleção de variáveis aleatórias independentes aproxima-se de uma distribuição normal.
#
# Por exemplo, dada coleção de variáveis aleatórias que seguem a distribuição uniforme no intervalo $[0, 1)$
#
# $$X_1, X_2, \ldots, X_n \sim \mathcal{U}(0, 1),$$
#
# Se tirarmos a média dessas variáveis, ela vai seguir uma distrbuição normal com média $\mu=0{,}5$. Isso é relevante porque existem testes estatísticos que supõem que os dados seguem uma distribuição gaussiana.
#
# Essa informação também pode ser usada como uma forma rudimentar de amostrar variáveis aleatórias seguindo uma distribuição aproximadamente normal. O Python possui formas mais sofisticadas de se fazer isso, mas é interesante vermos que conseguimos um resultado razoável com ferramentas simples.

# %% [markdown]
# <div style="background-color: #E2A038; border: #E2A038 solid 1px; margin-left: 2em; padding-left: 5px"><div style="background-color: #F5EEE3; width: 100%; padding: 10px">
#
# Escreva uma função que gera algumas variáveis aleatórias uniformemente distribuídas no intervalo $[0,1)$ e retorna o valor médio dessas amostras.
# </div></div>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.random.rand(1000)

np.average(a)
# Out:
# 0.4982008003921982

# %% [markdown]
# <div style="background-color: #E2A038; border: #E2A038 solid 1px; margin-left: 2em; padding-left: 5px"><div style="background-color: #F5EEE3; width: 100%; padding: 10px">
#
# A função que você gerou segue uma distribuição apriximadamente normal com médoa $0,5$. Utilize o PyPlot para gerar um histograma com mil variáveis aletórias coletadas da sua função.
#
# </div></div>

# %%
plt.hist(a)
# Out:
# (array([106.,  97.,  97., 114.,  96.,  89.,  91., 104., 112.,  94.]),
#  array([4.10221403e-04, 1.00334448e-01, 2.00258675e-01, 3.00182901e-01,
#         4.00107128e-01, 5.00031354e-01, 5.99955581e-01, 6.99879808e-01,
#         7.99804034e-01, 8.99728261e-01, 9.99652487e-01]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Distribuições do NumPy

# %% [markdown]
# Existem formas mais sofisticas de se gerar números aleatórios segundo uma distribuição normal. O NumPy implementa essa e diversas outras distribuições.

# %% [markdown]
# <div style="background-color: #E2A038; border: #E2A038 solid 1px; margin-left: 2em; padding-left: 5px"><div style="background-color: #F5EEE3; width: 100%; padding: 10px">
#
# Utilize `numpy.random.RandomState` para instanciar um objeto de números pseudoaleatórios  com um estado inicial bem definido.
# </div></div>

# %%
import numpy as np

rng = np.random.RandomState(1337)

# %% [markdown]
# <div style="background-color: #E2A038; border: #E2A038 solid 1px; margin-left: 2em; padding-left: 5px"><div style="background-color: #F5EEE3; width: 100%; padding: 10px">
#
# Utilize `RandomState` para amostrar números aleatórios de uma distribuição normal $\mathcal{N}(0,1)$.
# </div></div>

# %%
amostra_normal = rng.normal(0, 1, 100) #100 amostras centradas em 0 com desvio-padrão 1 (c, dp, n)

print(amostra_normal)
# Out:
# [-0.77572065 -0.12322816 -0.53693127  0.16537341  0.89985572  1.25719599
#   1.15406861 -0.6742258   0.88326667 -1.800741    0.31552402 -0.29894243
#   0.92326671 -0.86461042  0.9063239   0.14366537 -0.42878404  0.04363349
#  -1.15963013 -0.14458172  1.06269721  1.50348168  0.89047731  0.11018473
#  -0.28087837  0.47087678 -0.12265481  1.80971612 -0.21150403 -0.10491642
#   0.5600093  -1.1794564  -0.46780378 -1.74241319 -0.00370322 -2.17006719
#   0.42451005  0.14647864  0.05927444 -0.49125393 -1.01717308  0.4193072
#  -0.77136751  1.43788652  2.68676712  0.39673288  0.47692396  0.8159017
#  -0.50309222  0.1448642   0.03915845 -0.61283594  0.70088211  0.97686485
#  -0.63094152 -0.83860272 -0.43920366 -1.36452679 -1.27237114  0.86019089
#   0.91486046 -0.71286014  0.15607764  1.15855621 -0.49821012  1.67069107
#   0.43176528  0.42671205  0.98674599  0.9776806  -1.0646682   0.53884794
#   0.84308257  0.90072291 -0.80167733  0.48713081 -0.35839959  1.20297675
#   0.4586992  -1.11963082  0.3351304  -0.68690022  1.20681682  1.91752106
#   0.54219896  0.72235355 -0.17488135 -0.11599682 -1.98712683  0.00998292
#   0.07121492 -1.75004126  0.55443838  0.27454585  1.72070508 -2.39421276
#  -0.43833583  1.22198125  0.37437699 -1.38100426]

# %%
plt.hist(amostra_normal);

# %% [markdown]
# <div style="background-color: #E2A038; border: #E2A038 solid 1px; margin-left: 2em; padding-left: 5px"><div style="background-color: #F5EEE3; width: 100%; padding: 10px">
#
# Amostre $1.000$ números e plote um histograma.
# </div></div>

# %%
amostra_normal = rng.normal(0, 1, 1000)

# %%
plt.hist(amostra_normal);

# %% [markdown]
# <div style="background-color: #E2A038; border: #E2A038 solid 1px; margin-left: 2em; padding-left: 5px"><div style="background-color: #F5EEE3; width: 100%; padding: 10px">
#
# Você conhece outras distribuições? Verifique se elas estão no NumPy. Utilize, por exemplo, um comando <tt>dir</tt> na classe do gerador pseudoaleatório.
# </div></div>

# %%
rng = np.random.RandomState(1337)

amostra_uniforme = rng.uniform(0, 1, 100)

# %% [markdown]
# ## Sequências numéricas

# %% [markdown]
# Para essa atividade, baixe os arquivos de dados que estão no ColabWeb.

# %% [markdown]
# <div style="background-color: #E2A038; border: #E2A038 solid 1px; margin-left: 2em; padding-left: 5px"><div style="background-color: #F5EEE3; width: 100%; padding: 10px">
#
# Utilize a função `numpy.loadtxt` para carregar a sequência numérica do arquivo `data/lavras.txt`.
# </div></div>

# %%
import matplotlib.pyplot as plt
import numpy as np

lavras = np.loadtxt("lavras.txt")

# %%
lavras.shape
# Out:
# (384,)

# %% [markdown]
# <div style="background-color: #E2A038; border: #E2A038 solid 1px; margin-left: 2em; padding-left: 5px"><div style="background-color: #F5EEE3; width: 100%; padding: 10px">
#
# Gere um gráfico dessa sequência utilizando PyPlot.
# </div></div>

# %%
plt.plot(lavras)

plt.show()

# %% [markdown]
# <div style="background-color: #E2A038; border: #E2A038 solid 1px; margin-left: 2em; padding-left: 5px"><div style="background-color: #F5EEE3; width: 100%; padding: 10px">
#
# Use a função `figure` para criar a figura antes de plotar. O argumento `figsize` recebe uma tupla que especifica o tamanho da figura em polegadas. Use essa funcionalidade para gerar uma figura mais legível.
# </div></div>

# %%
fig = plt.figure(figsize=(30, 8))

plt.plot(lavras)
plt.show()

# %% [markdown]
# O gráfico gerado mostra o nível mensal de precipitação na cidade de Lavras (MG). Os dados foram coletados no período de janeiro de 1966 até dezembro de 1997.

# %% [markdown]
# <div style="background-color: #E2A038; border: #E2A038 solid 1px; margin-left: 2em; padding-left: 5px"><div style="background-color: #F5EEE3; width: 100%; padding: 10px">
#
# Isole os níveis de chuva no ano 1997.
# </div></div>

# %%
meses = ['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out', 'nov', 'dez']
anos = range(1966, 1998)

fig, ax = plt.subplots(figsize=(12, 6))

i = (1997 - anos[0]) * len(meses) #aqui, determina o intervalo em que os valores de 97 estão inseridos
f = i + len(meses)

ax.plot(meses, lavras[i:f])

plt.show()

# %% [markdown]
# <div style="background-color: #E2A038; border: #E2A038 solid 1px; margin-left: 2em; padding-left: 5px"><div style="background-color: #F5EEE3; width: 100%; padding: 10px">
#
# Isole os níveis de chuva no ano 1990.
# </div></div>

# %%
meses = ['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out', 'nov', 'dez']
anos = range(1966, 1998)

fig, ax = plt.subplots(figsize=(12, 6))

i = (1990 - anos[0]) * len(meses) #aqui, determina o intervalo em que os valores de 90 estão inseridos
f = i + len(meses)

ax.plot(meses, lavras[i:f])

plt.show()

# %% [markdown]
# <div style="background-color: #E2A038; border: #E2A038 solid 1px; margin-left: 2em; padding-left: 5px"><div style="background-color: #F5EEE3; width: 100%; padding: 10px">
#
# Utilizando `reshape`, transforme a sequência em uma matriz na qual cada linha é um ano.
# </div></div>

# %%
matriz = lavras.reshape((len(range(1966,1998)),len(meses)))

print(matriz)
# Out:
# [[5.150e+02 2.371e+02 2.242e+02 2.440e+01 1.160e+01 0.000e+00 4.900e+00
#   8.700e+00 3.230e+01 1.680e+02 2.651e+02 3.027e+02]
#  [3.930e+02 2.837e+02 1.152e+02 2.610e+01 6.000e-01 2.840e+01 0.000e+00
#   0.000e+00 5.100e+00 1.230e+02 2.576e+02 2.100e+02]
#  [1.960e+02 1.915e+02 7.640e+01 2.860e+01 2.000e+00 2.000e+00 3.300e+00
#   4.280e+01 6.680e+01 1.080e+02 8.100e+01 3.720e+02]
#  [2.540e+02 1.753e+02 1.476e+02 5.000e+01 3.320e+01 4.300e+01 4.700e+00
#   2.450e+01 2.020e+01 1.150e+02 2.915e+02 2.694e+02]
#  [3.450e+02 2.555e+02 1.060e+02 7.220e+01 1.680e+01 2.360e+01 2.610e+01
#   5.540e+01 5.740e+01 1.440e+02 2.228e+02 1.024e+02]
#  [2.590e+02 5.610e+01 4.970e+01 8.730e+01 2.700e+00 1.089e+02 6.000e-01
#   0.000e+00 4.890e+01 1.310e+02 2.946e+02 4.464e+02]
#  [1.970e+02 2.588e+02 2.040e+02 4.520e+01 3.260e+01 0.000e+00 9.440e+01
#   1.800e+01 7.280e+01 1.880e+02 4.171e+02 1.993e+02]
#  [2.020e+02 1.165e+02 1.117e+02 1.723e+02 6.040e+01 3.500e+01 8.200e+00
#   2.720e+01 4.220e+01 1.490e+02 1.337e+02 2.574e+02]
#  [2.120e+02 6.410e+01 4.262e+02 6.200e+01 3.540e+01 7.220e+01 0.000e+00
#   4.500e+00 1.520e+01 1.110e+02 7.190e+01 3.245e+02]
#  [1.730e+02 2.686e+02 4.720e+01 4.980e+01 1.780e+01 5.100e+00 2.540e+01
#   0.000e+00 5.000e+01 1.070e+02 3.317e+02 2.254e+02]
#  [7.600e+01 2.282e+02 1.269e+02 8.430e+01 1.234e+02 2.240e+01 6.860e+01
#   1.070e+02 1.960e+02 1.050e+02 1.664e+02 3.609e+02]
#  [2.500e+02 2.380e+01 2.794e+02 8.840e+01 5.100e+00 7.400e+00 0.000e+00
#   4.200e+01 1.280e+02 5.120e+01 2.732e+02 2.073e+02]
#  [4.100e+02 1.292e+02 9.010e+01 3.060e+01 1.002e+02 2.320e+01 4.610e+01
#   2.000e-01 4.300e+01 1.560e+02 2.186e+02 2.012e+02]
#  [2.050e+02 3.803e+02 2.042e+02 8.040e+01 8.600e+01 0.000e+00 8.180e+01
#   7.130e+01 7.300e+01 1.660e+02 2.356e+02 3.496e+02]
#  [4.890e+02 2.018e+02 6.100e+01 1.476e+02 8.800e+00 8.260e+01 0.000e+00
#   1.320e+01 4.500e+01 6.060e+01 2.290e+02 2.505e+02]
#  [2.820e+02 7.060e+01 1.172e+02 4.140e+01 2.540e+01 5.060e+01 0.000e+00
#   2.200e+01 5.700e+01 2.200e+02 2.532e+02 2.306e+02]
#  [3.520e+02 1.876e+02 3.432e+02 2.300e+01 1.600e+01 8.500e+00 2.180e+01
#   2.000e+00 4.400e+01 1.790e+02 1.360e+02 5.072e+02]
#  [2.384e+02 3.465e+02 2.460e+02 2.158e+02 1.408e+02 1.274e+02 5.460e+01
#   6.000e+00 3.690e+02 1.840e+02 1.936e+02 4.136e+02]
#  [1.720e+02 6.860e+01 1.012e+02 1.097e+02 4.660e+01 0.000e+00 0.000e+00
#   3.340e+01 1.130e+02 6.650e+01 2.328e+02 2.679e+02]
#  [4.480e+02 1.606e+02 2.251e+02 8.300e+00 2.120e+01 2.800e+00 0.000e+00
#   2.000e+00 6.070e+01 7.600e+01 2.626e+02 3.920e+02]
#  [1.260e+02 2.587e+02 1.477e+02 2.810e+01 8.990e+01 1.200e+00 8.040e+01
#   8.110e+01 1.760e+01 3.760e+01 1.402e+02 5.092e+02]
#  [2.050e+02 1.355e+02 1.790e+02 1.092e+02 5.660e+01 2.060e+01 4.000e+00
#   0.000e+00 9.190e+01 5.740e+01 1.690e+02 4.023e+02]
#  [1.380e+02 2.556e+02 1.117e+02 3.160e+01 3.380e+01 2.320e+01 9.500e+00
#   0.000e+00 5.320e+01 1.810e+02 1.538e+02 1.895e+02]
#  [2.700e+02 3.612e+02 2.728e+02 4.520e+01 0.000e+00 4.050e+01 3.140e+01
#   6.200e+00 7.140e+01 5.940e+01 1.234e+02 2.713e+02]
#  [1.140e+02 1.200e+02 1.150e+02 6.840e+01 9.260e+01 6.000e-01 3.480e+01
#   4.260e+01 7.140e+01 9.140e+01 1.814e+02 9.700e+01]
#  [5.430e+02 2.032e+02 2.189e+02 1.014e+02 2.000e+00 0.000e+00 7.400e+00
#   0.000e+00 4.660e+01 1.900e+02 1.015e+02 2.149e+02]
#  [7.180e+02 1.440e+02 2.378e+02 1.110e+02 9.390e+01 3.500e+00 1.410e+01
#   2.540e+01 1.580e+02 1.440e+02 2.300e+02 1.316e+02]
#  [1.940e+02 2.749e+02 1.342e+02 6.270e+01 2.800e+01 5.400e+01 0.000e+00
#   2.160e+01 5.540e+01 4.780e+01 1.020e+02 2.292e+02]
#  [4.210e+02 2.119e+02 2.738e+02 2.380e+01 1.983e+02 1.000e+01 3.500e+00
#   0.000e+00 0.000e+00 1.460e+02 1.274e+02 3.168e+02]
#  [2.000e+02 3.395e+02 1.248e+02 6.460e+01 6.560e+01 1.200e+00 1.000e+00
#   0.000e+00 3.860e+01 1.160e+02 1.920e+02 4.421e+02]
#  [1.740e+02 3.103e+02 1.291e+02 5.410e+01 8.460e+01 1.700e+01 2.000e-01
#   1.810e+01 1.490e+02 9.050e+01 3.632e+02 2.527e+02]
#  [3.833e+02 1.145e+02 9.650e+01 6.110e+01 4.100e+01 5.260e+01 5.600e+00
#   1.200e+00 3.880e+01 1.641e+02 1.948e+02 2.536e+02]]

# %% [markdown]
# <div style="background-color: #E2A038; border: #E2A038 solid 1px; margin-left: 2em; padding-left: 5px"><div style="background-color: #F5EEE3; width: 100%; padding: 10px">
#
# Isole os níveis de chuva em 1990 utilizando a matriz.
# </div></div>

# %%
print(matriz[1990 - 1966])
# Out:
# [114.  120.  115.   68.4  92.6   0.6  34.8  42.6  71.4  91.4 181.4  97. ]

# %% [markdown]
# <div style="background-color: #E2A038; border: #E2A038 solid 1px; margin-left: 2em; padding-left: 5px"><div style="background-color: #F5EEE3; width: 100%; padding: 10px">
#
# Encontre os valores médios, mínimos e máximos de chuva em mês.
# </div></div>

# %%
for i in anos:
    print(i)
    print("Média: ", np.average(matriz[i - 1966]), "Mínimo:", np.min(matriz[i - 1966]), "Máximo:", np.max(matriz[i - 1966]))
# Out:
# 1966
# Média:  149.50000000000003 Mínimo: 0.0 Máximo: 515.0
# 1967
# Média:  120.22500000000001 Mínimo: 0.0 Máximo: 393.0
# 1968
# Média:  97.53333333333335 Mínimo: 2.0 Máximo: 372.0
# 1969
# Média:  119.03333333333335 Mínimo: 4.7 Máximo: 291.5
# 1970
# Média:  118.93333333333334 Mínimo: 16.8 Máximo: 345.0
# 1971
# Média:  123.7666666666667 Mínimo: 0.0 Máximo: 446.4
# 1972
# Média:  143.93333333333334 Mínimo: 0.0 Máximo: 417.1
# 1973
# Média:  109.63333333333333 Mínimo: 8.2 Máximo: 257.4
# 1974
# Média:  116.58333333333333 Mínimo: 0.0 Máximo: 426.2
# 1975
# Média:  108.41666666666667 Mínimo: 0.0 Máximo: 331.7
# 1976
# Média:  138.75833333333333 Mínimo: 22.4 Máximo: 360.9
# 1977
# Média:  112.98333333333333 Mínimo: 0.0 Máximo: 279.4
# 1978
# Média:  120.7 Mínimo: 0.2 Máximo: 410.0
# 1979
# Média:  161.1 Mínimo: 0.0 Máximo: 380.3
# 1980
# Média:  132.42499999999998 Mínimo: 0.0 Máximo: 489.0
# 1981
# Média:  114.16666666666667 Mínimo: 0.0 Máximo: 282.0
# 1982
# Média:  151.69166666666666 Mínimo: 2.0 Máximo: 507.2
# 1983
# Média:  211.3083333333333 Mínimo: 6.0 Máximo: 413.6
# 1984
# Média:  100.97499999999998 Mínimo: 0.0 Máximo: 267.9
# 1985
# Média:  138.275 Mínimo: 0.0 Máximo: 448.0
# 1986
# Média:  126.47500000000001 Mínimo: 1.2 Máximo: 509.2
# 1987
# Média:  119.20833333333333 Mínimo: 0.0 Máximo: 402.3
# 1988
# Média:  98.40833333333335 Mínimo: 0.0 Máximo: 255.6
# 1989
# Média:  129.4 Mínimo: 0.0 Máximo: 361.2
# 1990
# Média:  85.76666666666665 Mínimo: 0.6 Máximo: 181.4
# 1991
# Média:  135.74166666666667 Mínimo: 0.0 Máximo: 543.0
# 1992
# Média:  167.60833333333332 Mínimo: 3.5 Máximo: 718.0
# 1993
# Média:  100.31666666666666 Mínimo: 0.0 Máximo: 274.9
# 1994
# Média:  144.375 Mínimo: 0.0 Máximo: 421.0
# 1995
# Média:  132.11666666666667 Mínimo: 0.0 Máximo: 442.1
# 1996
# Média:  136.9 Mínimo: 0.2 Máximo: 363.2
# 1997
# Média:  117.25833333333333 Mínimo: 1.2 Máximo: 383.3

# %% [markdown]
# Um tipo de gráfico muito útil é o gráfico de barras. O Matplotlib permite gerar gráficos de barras com a função `bar`. A assinatura completa dessa função é
#
# ```Python
# plt.bar(x, height, width=0.8, bottom=None, *, align='center', data=None, **kwargs)
# ```
#
# Então a função exige pelo menos dois argumentos posicionais: um para os valores ou rótulos de cada barra e outro com as alturas das barras.

# %% [markdown]
# <div style="background-color: #E2A038; border: #E2A038 solid 1px; margin-left: 2em; padding-left: 5px"><div style="background-color: #F5EEE3; width: 100%; padding: 10px">
#
# Gere um gráfico de barras com o nível médio de chuva em cada mês.
# </div></div>

# %%
meses = ['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out', 'nov', 'dez']

# %%
med = []

for i in range(len(meses)):
    med.append(np.average(matriz[i:]))

plt.bar(meses,med)

plt.show()

# %% [markdown]
# O escore padrão (ou $z$-*score*) é uma estatística utilizada para normalizar os dados. Ela transforma uma amostra para uma distribuição que tem média aproximadamente zero e desvio padrão aproximadamente 1.
#
# Para encontrar os escores padrão de uma amostra, subtraia a média e divida pelo seu desvio padrão.

# %% [markdown]
# <div style="background-color: #E2A038; border: #E2A038 solid 1px; margin-left: 2em; padding-left: 5px"><div style="background-color: #F5EEE3; width: 100%; padding: 10px">
#
# Encontre o valor médio de chuva em cada ano.
# </div></div>

# %%
medA = []
escore = []

for i in range(len(lavras)): ##media a cada ano, depois 
    medA.append(np.average(lavras[i]))
    escore.append((medA[i] - np.average(lavras))/np.std(lavras))

print(np.average(escore))
print(np.average(lavras))
# Out:
# 7.170190367370803e-17
# 127.60989583333333

# %% [markdown]
# <div style="background-color: #E2A038; border: #E2A038 solid 1px; margin-left: 2em; padding-left: 5px"><div style="background-color: #F5EEE3; width: 100%; padding: 10px">
#
# Encontre o desvio padrão da chuva em cada ano.
# </div></div>

# %%
print(np.std(escore))
print(np.std(lavras))
# Out:
# 0.9999999999999998
# 121.9081226613817
